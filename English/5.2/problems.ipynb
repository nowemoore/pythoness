# %% [markdown]
# # In-Class Problems

# %% [markdown]
# ## ⭐ Task 01
#
# Find and import a kaggle database with at least one numerical column.

# %% [markdown]
# ## ⭐ Task 02
#
# Read the CSV file and save said numerical column as a list of numbers using `pandas`.

# %% [markdown]
# ## ⭐ Task 03
#
# Use any sorting algorithm to sort data in this list.

# %% [markdown]
# ## ⭐ Task 04
#
# Without looking through the list of data, write down a list of three values that you think could be included in this data. Then use any searching algorithm to find the index of this data.
